# %% [markdown]
# It is a Grid Search based SLAM implementation using LIDAR data using the following:
#  - basic : we rotate the destination (later) pcd to destination's (local) grid points to score against source (former) pcd
#  - adaptive grid : grid is interpolated based on velocity instead of distance ; this assumes that there are no sudden acceleration or impulsive forces or jerks
#  - 2d map : creates a 2d map of the environment instead of 3d
#  - parallel : the grid search for every pose has been parallelized on CPU cores

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import gc
from tqdm import *
import os
import copy
import sys
import time
from collections import Counter, deque
from multiprocessing import Pool, cpu_count

import transforms3d

from sklearn.manifold import TSNE, LocallyLinearEmbedding
from sklearn.cluster import MeanShift

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import ipyvolume as ipv
import open3d as o3d

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
# %matplotlib notebook

# %% [markdown]
# ### Set paths and file names

# %%
# ATM_PATH = "/Users/saby/Projects/atm/"
ATM_PATH = "/home/nilesh/Prashant/sabyasachi/atm"
DATA_PATH = os.path.join(ATM_PATH, "data", "data", "datasets")

IISC_DATA_PATH = os.path.join(DATA_PATH, "IISC")
# EXP_PATH = os.path.join(IISC_DATA_PATH, "2019-02-26","ref_run_ccw_r")
EXP_PATH = os.path.join(IISC_DATA_PATH, "2019-03-30","15-41-43-mule1-auto-slam2d_test_track_ccw_5loops")

LIDAR_PCD_PATH = os.path.join(EXP_PATH, "complete")
LIDAR_CSV_PATH = os.path.join(IISC_DATA_PATH, "lidar.csv")

MAP_FILE = 'map_5loops.pcd'
POSE_FILE = 'pose_5loops.json'

# %% [markdown]
# ### Set constants and flags

# %%
# FIRST_PCD = 200
# FINAL_PCD = 210
# FIRST_PCD = 2
# FINAL_PCD = 805

FIRST_PCD = 2
FINAL_PCD = 4694

VOXEL_SZ = 0.2
MAKE_2D = False
APPLY_CLUSTER = False

plt.rcParams['figure.figsize'] = [10, 10]

X_GRID = np.arange(-0.2, 0.225, 0.025)
Y_GRID = np.arange(-0.2, 0.225, 0.025)
THETA_GRID = np.arange(-2, 2.25, 0.25)
print("No of grid pts to evaluate per pose: {}".format(X_GRID.shape[0]*Y_GRID.shape[0]*THETA_GRID.shape[0]))
# Out:
# No of grid pts to evaluate per pose: 4913

# %% [markdown]
# ### Functions for pcd io

# %%
def pose2matrix(translation_list, rotation_angle_list):
    trans_vec = np.array(translation_list)
    rot_ang = [np.deg2rad(ang) for ang in rotation_angle_list ]
    rot_mat = transforms3d.euler.euler2mat(rot_ang[0], rot_ang[1], rot_ang[2])
    zoom = np.ones(3)
    transform_mat = transforms3d.affines.compose(trans_vec, rot_mat, zoom)
    return transform_mat

def filter_pcd(old_pcd,
               apply_downsample = True,
               downsample_voxel_size = VOXEL_SZ,
               
               apply_outlier_removal = True,
               downsample_radius = 1,
               downsample_neighbors = 20,
               
               apply_crop = True,
               crop_min_arr = np.array([-100,-100,0]),
               crop_max_arr = np.array([100,100,100]),
               
               apply_cluster = True,
               cluster_neighbours = 30,
               cluster_labels = 2):
    np.random.seed(0)
    pcd = copy.deepcopy(old_pcd)
    
    if apply_downsample:
        voxel_down_pcd = o3d.geometry.voxel_down_sample(pcd, voxel_size = downsample_voxel_size)
        pcd = voxel_down_pcd

    if apply_outlier_removal:
        denser_pcd, ind = o3d.geometry.radius_outlier_removal(pcd,
                                                              nb_points = downsample_neighbors,
                                                              radius    = downsample_radius)
        pcd = denser_pcd
    
    if apply_crop:
        cropped_pcd = o3d.geometry.crop_point_cloud(pcd, crop_min_arr, crop_max_arr)
        pcd = cropped_pcd

    if apply_cluster:
        few_pts = np.asarray(pcd.points)
        try:
            few_pts_reduced = LocallyLinearEmbedding(n_neighbors=cluster_neighbours, n_components=2).fit_transform(few_pts)
        except Exception as e:
            try:
                few_pts_reduced = LocallyLinearEmbedding(n_neighbors=cluster_neighbours, n_components=2, eigen_solver='dense').fit_transform(few_pts)
            except Exception as e:
                few_pts_reduced = few_pts
        clf = MeanShift().fit(few_pts_reduced)
        pcd.points = o3d.utility.Vector3dVector(few_pts[clf.labels_ < cluster_labels])
    
    return pcd

def make_2d(pcd):
    new_pcd = copy.deepcopy(pcd)
    new_pts = np.concatenate([np.asarray(pcd.points)[:,:-1],np.zeros((len(pcd.points),1))], axis=1)
    new_pcd.points = o3d.utility.Vector3dVector(new_pts)
    return new_pcd

def read_pcd(pcd_id):
    pcd_file = str(pcd_id) + ".pcd"
    pcd = o3d.io.read_point_cloud(os.path.join(LIDAR_PCD_PATH, pcd_file))
    return pcd

def draw_pcd(pcd, where='mat_3d'):
    if where is 'opn_nb':
        visualizer = o3d.JVisualizer()
        visualizer.add_geometry(pcd)
        visualizer.show()
    elif where is 'opn_view':
        o3d.visualization.draw_geometries([pcd], width=1280, height=800)
    elif where is 'mat_3d':
        pts = np.asarray(pcd.points)
        plt.scatter(pts[:,0], pts[:,1], pts[:,2])
        plt.show()
    elif where is 'mat_2d':
        pts = np.asarray(pcd.points)
        plt.scatter(pts[:,0], pts[:,1])
        plt.show()
        
def draw_registration_result(src_pcd, dst_pcd, x_pt, y_pt, theta):    
    src_pcd_tmp = copy.deepcopy(src_pcd)
    dst_pcd_tmp = copy.deepcopy(dst_pcd)
    
    src_pcd_tmp.paint_uniform_color([1, 0, 0])  # red source
    dst_pcd_tmp.paint_uniform_color([0, 0, 1])  # blue target
    
    transform_mat = pose2matrix([x_pt, y_pt, 0], [0,0,theta])
    dst_pcd_tmp.transform(transform_mat)
    
    visualizer = o3d.JVisualizer()
    visualizer.add_geometry(src_pcd_tmp)
    visualizer.add_geometry(dst_pcd_tmp)
    visualizer.show()

# %% [markdown]
# ### Functions for pose estimation and scoring

# %%
def score_pts(src_pcd, dst_pcd, trans_arr=np.zeros(3), rot_ang=np.zeros(3)):
    NEIGHB_RADIUS = VOXEL_SZ
    
    src_tmp_pcd = copy.deepcopy(src_pcd)
    dst_tmp_pcd = copy.deepcopy(dst_pcd)
    
    transform_mat = pose2matrix(trans_arr, rot_ang)
    # Note: we apply transformation on target pcd to directly get pose (without sign change)
    dst_tmp_pcd.transform(transform_mat)
    
    score = o3d.registration.evaluate_registration(src_tmp_pcd, dst_tmp_pcd, NEIGHB_RADIUS)
    
    fit = score.fitness
    rmse = score.inlier_rmse
    n_pairs = np.asarray(score.correspondence_set).shape[0]
    return rmse, fit, n_pairs

def parallel_thread(parallel_arg):
    grid_pts, previous_pose, previous_velocity = parallel_arg[0], parallel_arg[1], parallel_arg[2]
    x_pt, y_pt, theta_pt = grid_pts[0], grid_pts[1], grid_pts[2]
    x_src, y_src, theta_src = previous_pose[0], previous_pose[1], previous_pose[2]
    x_vel, y_vel, theta_vel = previous_velocity[0], previous_velocity[1], previous_velocity[2]
    
    x = x_src + x_vel + x_pt
    y = y_src + y_vel + y_pt
    t = theta_src + theta_vel + theta_pt
    rmse, fit, n_pairs = score_pts(map_pcd, new_pcd,
                                   trans_arr = [x, y, 0],
                                   rot_ang   = [0, 0, t])
    result = {'x' : x,
              'y' : y,
              'theta' : t,
              
              'x_vel' : x_vel + x_pt,
              'y_vel' : y_vel + y_pt,
              'theta_vel' : theta_vel + theta_pt,
              
              'rmse' : rmse,
              'fit' : fit,
              'n_pairs' : n_pairs}
#     print(grid_pts)
    return result

# %% [markdown]
# ### Implementation

# %% [markdown]
# #### Create initial map

# %%
map_pcd = read_pcd(FIRST_PCD)
map_pcd = filter_pcd(map_pcd, apply_cluster=APPLY_CLUSTER)
if MAKE_2D:
    map_pcd = make_2d(map_pcd)
print(map_pcd)
# Out:
# geometry::PointCloud with 3621 points.

# %% [markdown]
# #### Initialize pose arrays

# %%
pose_list = []
global_origin_pt = {'x' : 0,
                    'y' : 0,
                    'theta' : 0,
                    
                    'x_vel' : 0,
                    'y_vel' : 0,
                    'theta_vel' : 0,
                    
                    'rmse' : 0,
                    'fit' : 1,
                    'n_pairs' : np.asarray(map_pcd.points).shape[0]}
pose_list.append(global_origin_pt)

# %% [markdown]
# #### Iterate over all subsequent pcds for local pose estimation and building the map

# %%
for pcd_idx in tqdm_notebook(range(FIRST_PCD+1, FINAL_PCD)):
    # Read next pcd and filter it
    new_pcd = read_pcd(pcd_idx)
    new_pcd = filter_pcd(new_pcd, apply_cluster=APPLY_CLUSTER)
    if MAKE_2D:
        new_pcd = make_2d(new_pcd)

    # Extract last pose
    x_src, y_src, theta_src = pose_list[-1]['x'], pose_list[-1]['y'], pose_list[-1]['theta']
    x_vel, y_vel, theta_vel = pose_list[-1]['x_vel'], pose_list[-1]['y_vel'], pose_list[-1]['theta_vel']
    
    # Extract all grid pts
    parallel_args = [([x_pt, y_pt, theta], [x_src, y_src, theta_src], [x_vel, y_vel, theta_vel])\
                     for x_pt in X_GRID for y_pt in Y_GRID for theta in THETA_GRID]
    
    # Score on all grid pts
#     process_pool = Pool(cpu_count()-1)
#     score_list = [each for each in process_pool.imap_unordered(parallel_thread, parallel_args)]
#     process_pool.terminate()
    
    score_list = [parallel_thread(each) for each in parallel_args]
    
    # Extract pose with best matching score
    df_score = pd.DataFrame(score_list)
    new_pose_pt = df_score.iloc[df_score.fit.argmax()].to_dict()
    pose_list.append(new_pose_pt)

    # Transform this pcd based on the best pose
    new_tmp_pcd = copy.deepcopy(new_pcd)
    transform_mat = pose2matrix([new_pose_pt['x'], new_pose_pt['y'], 0],
                                 [0, 0, new_pose_pt['theta']])
    new_tmp_pcd.transform(transform_mat)

    # Add the current transformed pcd to the map
    map_pcd.points = o3d.utility.Vector3dVector(np.concatenate((np.asarray(map_pcd.points),
                                                                 np.asarray(new_tmp_pcd.points)), axis=0))

    map_pcd = filter_pcd(map_pcd, apply_cluster=False)
    if MAKE_2D:
        map_pcd = make_2d(map_pcd)
    
    # Checkpoint the new map and pose array to files
    o3d.io.write_point_cloud(MAP_FILE, map_pcd)
    pd.DataFrame(pose_list).to_json(POSE_FILE, orient='records', lines=True)
    if pcd_idx % 500 == 0:
        o3d.io.write_point_cloud(MAP_FILE[:-4] + str(pcd_idx) + ".pcd", map_pcd)
    
    gc.collect()
    
    print(map_pcd)
# Out:
# HBox(children=(IntProgress(value=0, max=4691), HTML(value='')))
# geometry::PointCloud with 3219 points.
# geometry::PointCloud with 4043 points.
# geometry::PointCloud with 4062 points.
# geometry::PointCloud with 4040 points.
# geometry::PointCloud with 4129 points.
# geometry::PointCloud with 4275 points.
# geometry::PointCloud with 4406 points.
# geometry::PointCloud with 4321 points.
# geometry::PointCloud with 4368 points.
# geometry::PointCloud with 4274 points.
# geometry::PointCloud with 4279 points.
# geometry::PointCloud with 4643 points.
# geometry::PointCloud with 4508 points.
# geometry::PointCloud with 4541 points.
# geometry::PointCloud with 4003 points.
# geometry::PointCloud with 4559 points.
# geometry::PointCloud with 4282 points.
# geometry::PointCloud with 4099 points.
# geometry::PointCloud with 4039 points.
# geometry::PointCloud with 4014 points.
# geometry::PointCloud with 4046 points.
# geometry::PointCloud with 3936 points.
# geometry::PointCloud with 3857 points.
# geometry::PointCloud with 3892 points.
# geometry::PointCloud with 3892 points.
# geometry::PointCloud with 3910 points.
# geometry::PointCloud with 4043 points.
# geometry::PointCloud with 4087 points.
# geometry::PointCloud with 4107 points.
# geometry::PointCloud with 4188 points.
# geometry::PointCloud with 3985 points.
# geometry::PointCloud with 3971 points.
# geometry::PointCloud with 4015 points.
# geometry::PointCloud with 4157 points.
# geometry::PointCloud with 4339 points.
# geometry::PointCloud with 4190 points.
# geometry::PointCloud with 4407 points.
# geometry::PointCloud with 4502 points.
# geometry::PointCloud with 4629 points.
# geometry::PointCloud with 4602 points.
# geometry::PointCloud with 4947 points.
# geometry::PointCloud with 4977 points.
# geometry::PointCloud with 4830 points.
# geometry::PointCloud with 4769 points.
# geometry::PointCloud with 4706 points.
# geometry::PointCloud with 4783 points.
# geometry::PointCloud with 4874 points.
# geometry::PointCloud with 5049 points.
# geometry::PointCloud with 5067 points.
# geometry::PointCloud with 5096 points.
# geometry::PointCloud with 5233 points.
# geometry::PointCloud with 5100 points.
# geometry::PointCloud with 5481 points.
# geometry::PointCloud with 5577 points.
# geometry::PointCloud with 5842 points.
# geometry::PointCloud with 5901 points.
# geometry::PointCloud with 5632 points.
# geometry::PointCloud with 6090 points.
# geometry::PointCloud with 6007 points.
# geometry::PointCloud with 6405 points.
# geometry::PointCloud with 6025 points.
# geometry::PointCloud with 6319 points.
# geometry::PointCloud with 5880 points.
# geometry::PointCloud with 5469 points.
# geometry::PointCloud with 5710 points.
# geometry::PointCloud with 5860 points.
# geometry::PointCloud with 6308 points.
# geometry::PointCloud with 6373 points.
# geometry::PointCloud with 6737 points.
# geometry::PointCloud with 6665 points.
# geometry::PointCloud with 6963 points.
# geometry::PointCloud with 7257 points.
# geometry::PointCloud with 7526 points.
# geometry::PointCloud with 7895 points.
# geometry::PointCloud with 8195 points.
# geometry::PointCloud with 8525 points.
# geometry::PointCloud with 8829 points.
# geometry::PointCloud with 8603 points.
# geometry::PointCloud with 9029 points.
# geometry::PointCloud with 9426 points.
# geometry::PointCloud with 9813 points.
# geometry::PointCloud with 10089 points.
# geometry::PointCloud with 9831 points.
# geometry::PointCloud with 9795 points.
# geometry::PointCloud with 10192 points.
# geometry::PointCloud with 9484 points.
# geometry::PointCloud with 9684 points.
# geometry::PointCloud with 10099 points.
# geometry::PointCloud with 10200 points.
# geometry::PointCloud with 9423 points.
# geometry::PointCloud with 9266 points.
# geometry::PointCloud with 9184 points.
# geometry::PointCloud with 8833 points.
# geometry::PointCloud with 8453 points.
# geometry::PointCloud with 8828 points.
# geometry::PointCloud with 8670 points.
# geometry::PointCloud with 9098 points.
# geometry::PointCloud with 9315 points.
# geometry::PointCloud with 9692 points.
# geometry::PointCloud with 9835 points.
# geometry::PointCloud with 10213 points.
# geometry::PointCloud with 10383 points.
# geometry::PointCloud with 10236 points.
# geometry::PointCloud with 10474 points.
# geometry::PointCloud with 10732 points.
# geometry::PointCloud with 10931 points.
# geometry::PointCloud with 11134 points.
# geometry::PointCloud with 11447 points.
# geometry::PointCloud with 11599 points.
# geometry::PointCloud with 11850 points.
# geometry::PointCloud with 11988 points.
# geometry::PointCloud with 10690 points.
# geometry::PointCloud with 10372 points.
# geometry::PointCloud with 10149 points.
# geometry::PointCloud with 10078 points.
# geometry::PointCloud with 10380 points.
# geometry::PointCloud with 10498 points.
# geometry::PointCloud with 10781 points.
# geometry::PointCloud with 10893 points.
# geometry::PointCloud with 10814 points.
# geometry::PointCloud with 10899 points.
# geometry::PointCloud with 10990 points.
# geometry::PointCloud with 11031 points.
# geometry::PointCloud with 11121 points.
# geometry::PointCloud with 11155 points.
# geometry::PointCloud with 11583 points.
# geometry::PointCloud with 11425 points.
# geometry::PointCloud with 11672 points.
# geometry::PointCloud with 11784 points.
# geometry::PointCloud with 12025 points.
# geometry::PointCloud with 12194 points.
# geometry::PointCloud with 12211 points.
# geometry::PointCloud with 12311 points.
# geometry::PointCloud with 12435 points.
# geometry::PointCloud with 11267 points.
# geometry::PointCloud with 11540 points.
# geometry::PointCloud with 11756 points.
# geometry::PointCloud with 12043 points.
# geometry::PointCloud with 12180 points.
# geometry::PointCloud with 12260 points.
# geometry::PointCloud with 12371 points.
# geometry::PointCloud with 12426 points.
# geometry::PointCloud with 12493 points.
# geometry::PointCloud with 12626 points.
# geometry::PointCloud with 12701 points.
# geometry::PointCloud with 12607 points.
# geometry::PointCloud with 12675 points.
# geometry::PointCloud with 12692 points.
# geometry::PointCloud with 12745 points.
# geometry::PointCloud with 12799 points.
# geometry::PointCloud with 12827 points.
# geometry::PointCloud with 13022 points.
# geometry::PointCloud with 13144 points.
# geometry::PointCloud with 13217 points.
# geometry::PointCloud with 13304 points.
# geometry::PointCloud with 13322 points.
# geometry::PointCloud with 13347 points.
# geometry::PointCloud with 13380 points.
# geometry::PointCloud with 13348 points.
# geometry::PointCloud with 13433 points.
# geometry::PointCloud with 13359 points.
# geometry::PointCloud with 13200 points.
# geometry::PointCloud with 13182 points.
# geometry::PointCloud with 13238 points.
# geometry::PointCloud with 11502 points.
# geometry::PointCloud with 11635 points.
# geometry::PointCloud with 11888 points.
# geometry::PointCloud with 12022 points.
# geometry::PointCloud with 12222 points.
# geometry::PointCloud with 12282 points.
# geometry::PointCloud with 12339 points.
# geometry::PointCloud with 12230 points.
# geometry::PointCloud with 12319 points.
# geometry::PointCloud with 12373 points.
# geometry::PointCloud with 12211 points.
# geometry::PointCloud with 12238 points.
# geometry::PointCloud with 12301 points.
# geometry::PointCloud with 12367 points.
# geometry::PointCloud with 12436 points.
# geometry::PointCloud with 12500 points.
# geometry::PointCloud with 12560 points.
# geometry::PointCloud with 12626 points.
# geometry::PointCloud with 12759 points.
# geometry::PointCloud with 12830 points.
# geometry::PointCloud with 12898 points.
# geometry::PointCloud with 12971 points.
# geometry::PointCloud with 13005 points.
# geometry::PointCloud with 13046 points.
# geometry::PointCloud with 13109 points.
# geometry::PointCloud with 13177 points.
# geometry::PointCloud with 13200 points.
# geometry::PointCloud with 12950 points.
# geometry::PointCloud with 12714 points.
# geometry::PointCloud with 12853 points.
# geometry::PointCloud with 12879 points.
# geometry::PointCloud with 13039 points.
# geometry::PointCloud with 13068 points.
# geometry::PointCloud with 12848 points.
# geometry::PointCloud with 12909 points.
# geometry::PointCloud with 12928 points.
# geometry::PointCloud with 12960 points.
# geometry::PointCloud with 12982 points.
# geometry::PointCloud with 12856 points.
# geometry::PointCloud with 12884 points.
# geometry::PointCloud with 11778 points.
# geometry::PointCloud with 11940 points.
# geometry::PointCloud with 12125 points.
# geometry::PointCloud with 12210 points.
# geometry::PointCloud with 12249 points.
# geometry::PointCloud with 12393 points.
# geometry::PointCloud with 12448 points.
# geometry::PointCloud with 12484 points.
# geometry::PointCloud with 12470 points.
# geometry::PointCloud with 12566 points.
# geometry::PointCloud with 12581 points.
# geometry::PointCloud with 12589 points.
# geometry::PointCloud with 12625 points.
# geometry::PointCloud with 12676 points.
# geometry::PointCloud with 12633 points.
# geometry::PointCloud with 12652 points.
# geometry::PointCloud with 12678 points.
# geometry::PointCloud with 12748 points.
# geometry::PointCloud with 12761 points.
# geometry::PointCloud with 12802 points.
# geometry::PointCloud with 12843 points.
# geometry::PointCloud with 12863 points.
# geometry::PointCloud with 12902 points.
# geometry::PointCloud with 12829 points.
# geometry::PointCloud with 12877 points.
# geometry::PointCloud with 11826 points.
# geometry::PointCloud with 11880 points.
# geometry::PointCloud with 11965 points.
# geometry::PointCloud with 12077 points.
# geometry::PointCloud with 12140 points.
# geometry::PointCloud with 12311 points.
# geometry::PointCloud with 12326 points.
# geometry::PointCloud with 12421 points.
# geometry::PointCloud with 12420 points.
# geometry::PointCloud with 12462 points.
# geometry::PointCloud with 12490 points.
# geometry::PointCloud with 12576 points.
# geometry::PointCloud with 12664 points.
# geometry::PointCloud with 12683 points.
# geometry::PointCloud with 12706 points.
# geometry::PointCloud with 12693 points.
# geometry::PointCloud with 12725 points.
# geometry::PointCloud with 12824 points.
# geometry::PointCloud with 12849 points.
# geometry::PointCloud with 12928 points.
# geometry::PointCloud with 13041 points.
# geometry::PointCloud with 13037 points.
# geometry::PointCloud with 13065 points.
# geometry::PointCloud with 13125 points.
# geometry::PointCloud with 13090 points.
# geometry::PointCloud with 13161 points.
# geometry::PointCloud with 13252 points.
# geometry::PointCloud with 13309 points.
# geometry::PointCloud with 13352 points.
# geometry::PointCloud with 13326 points.
# geometry::PointCloud with 13337 points.
# geometry::PointCloud with 13404 points.
# geometry::PointCloud with 13377 points.
# geometry::PointCloud with 13225 points.
# geometry::PointCloud with 13226 points.
# geometry::PointCloud with 13259 points.
# geometry::PointCloud with 13285 points.
# geometry::PointCloud with 13243 points.
# geometry::PointCloud with 13269 points.
# geometry::PointCloud with 13304 points.
# geometry::PointCloud with 13294 points.
# geometry::PointCloud with 13325 points.
# geometry::PointCloud with 13110 points.
# geometry::PointCloud with 13198 points.
# geometry::PointCloud with 13309 points.
# geometry::PointCloud with 13424 points.
# geometry::PointCloud with 13506 points.
# geometry::PointCloud with 13451 points.
# geometry::PointCloud with 13001 points.
# geometry::PointCloud with 13111 points.
# geometry::PointCloud with 13147 points.
# geometry::PointCloud with 13243 points.
# geometry::PointCloud with 13486 points.
# geometry::PointCloud with 13502 points.
# geometry::PointCloud with 13570 points.
# geometry::PointCloud with 13675 points.
# geometry::PointCloud with 13768 points.
# geometry::PointCloud with 13963 points.
# geometry::PointCloud with 14091 points.
# geometry::PointCloud with 14216 points.
# geometry::PointCloud with 14356 points.
# geometry::PointCloud with 14481 points.
# geometry::PointCloud with 14598 points.
# geometry::PointCloud with 14777 points.
# geometry::PointCloud with 14873 points.
# geometry::PointCloud with 12978 points.
# geometry::PointCloud with 13135 points.
# geometry::PointCloud with 13360 points.
# geometry::PointCloud with 13617 points.
# geometry::PointCloud with 13723 points.
# geometry::PointCloud with 13911 points.
# geometry::PointCloud with 14093 points.
# geometry::PointCloud with 14194 points.
# geometry::PointCloud with 14285 points.
# geometry::PointCloud with 14620 points.
# geometry::PointCloud with 14712 points.
# geometry::PointCloud with 14801 points.
# geometry::PointCloud with 14874 points.
# geometry::PointCloud with 14983 points.
# geometry::PointCloud with 15071 points.
# geometry::PointCloud with 15211 points.
# geometry::PointCloud with 15290 points.
# geometry::PointCloud with 15350 points.
# geometry::PointCloud with 15427 points.
# geometry::PointCloud with 15534 points.
# geometry::PointCloud with 15675 points.
# geometry::PointCloud with 15743 points.
# geometry::PointCloud with 15802 points.
# geometry::PointCloud with 15883 points.
# geometry::PointCloud with 15950 points.
# geometry::PointCloud with 16024 points.
# geometry::PointCloud with 16115 points.
# geometry::PointCloud with 16227 points.
# geometry::PointCloud with 15645 points.
# geometry::PointCloud with 15696 points.
# geometry::PointCloud with 15895 points.
# geometry::PointCloud with 15990 points.
# geometry::PointCloud with 16123 points.
# geometry::PointCloud with 16226 points.
# geometry::PointCloud with 16328 points.
# geometry::PointCloud with 16467 points.
# geometry::PointCloud with 16560 points.
# geometry::PointCloud with 16590 points.
# geometry::PointCloud with 16627 points.
# geometry::PointCloud with 16697 points.
# geometry::PointCloud with 16787 points.
# geometry::PointCloud with 16853 points.
# geometry::PointCloud with 16912 points.
# geometry::PointCloud with 16984 points.
# geometry::PointCloud with 17208 points.
# geometry::PointCloud with 17263 points.
# geometry::PointCloud with 17318 points.
# geometry::PointCloud with 17374 points.
# geometry::PointCloud with 17476 points.
# geometry::PointCloud with 17552 points.
# geometry::PointCloud with 17623 points.
# geometry::PointCloud with 17729 points.
# geometry::PointCloud with 17858 points.
# geometry::PointCloud with 17865 points.
# geometry::PointCloud with 17959 points.
# geometry::PointCloud with 18045 points.
# geometry::PointCloud with 18112 points.
# geometry::PointCloud with 18259 points.
# geometry::PointCloud with 18352 points.
# geometry::PointCloud with 18455 points.
# geometry::PointCloud with 18534 points.
# geometry::PointCloud with 18606 points.
# geometry::PointCloud with 18678 points.
# geometry::PointCloud with 18713 points.
# geometry::PointCloud with 18791 points.
# geometry::PointCloud with 18867 points.
# geometry::PointCloud with 18936 points.
# geometry::PointCloud with 19018 points.
# geometry::PointCloud with 19066 points.
# geometry::PointCloud with 19053 points.
# geometry::PointCloud with 19146 points.
# geometry::PointCloud with 19215 points.
# geometry::PointCloud with 19272 points.
# geometry::PointCloud with 19328 points.
# geometry::PointCloud with 19393 points.
# geometry::PointCloud with 19464 points.
# geometry::PointCloud with 19508 points.
# geometry::PointCloud with 19588 points.
# geometry::PointCloud with 19643 points.
# geometry::PointCloud with 19704 points.
# geometry::PointCloud with 16398 points.
# geometry::PointCloud with 16559 points.
# geometry::PointCloud with 16739 points.
# geometry::PointCloud with 16985 points.
# geometry::PointCloud with 17158 points.
# geometry::PointCloud with 17230 points.
# geometry::PointCloud with 17301 points.
# geometry::PointCloud with 16248 points.
# geometry::PointCloud with 16348 points.
# geometry::PointCloud with 16463 points.
# geometry::PointCloud with 16558 points.
# geometry::PointCloud with 16673 points.
# geometry::PointCloud with 16097 points.
# geometry::PointCloud with 15958 points.
# geometry::PointCloud with 16053 points.
# geometry::PointCloud with 16196 points.
# geometry::PointCloud with 16303 points.
# geometry::PointCloud with 16548 points.
# geometry::PointCloud with 16654 points.
# geometry::PointCloud with 16777 points.
# geometry::PointCloud with 16885 points.
# geometry::PointCloud with 16986 points.
# geometry::PointCloud with 17083 points.
# geometry::PointCloud with 17158 points.
# geometry::PointCloud with 17302 points.
# geometry::PointCloud with 17376 points.
# geometry::PointCloud with 17424 points.
# geometry::PointCloud with 17486 points.
# geometry::PointCloud with 17554 points.
# geometry::PointCloud with 17617 points.
# geometry::PointCloud with 17682 points.
# geometry::PointCloud with 17733 points.
# geometry::PointCloud with 17796 points.
# geometry::PointCloud with 17538 points.
# geometry::PointCloud with 17596 points.
# geometry::PointCloud with 17668 points.
# geometry::PointCloud with 17698 points.
# geometry::PointCloud with 17773 points.
# geometry::PointCloud with 17805 points.
# geometry::PointCloud with 17845 points.
# geometry::PointCloud with 17897 points.
# geometry::PointCloud with 17946 points.
# geometry::PointCloud with 17975 points.
# geometry::PointCloud with 18025 points.
# geometry::PointCloud with 18066 points.
# geometry::PointCloud with 18116 points.
# geometry::PointCloud with 18149 points.
# geometry::PointCloud with 18190 points.
# geometry::PointCloud with 18212 points.
# geometry::PointCloud with 18244 points.
# geometry::PointCloud with 18265 points.
# geometry::PointCloud with 18293 points.
# geometry::PointCloud with 18322 points.
# geometry::PointCloud with 18351 points.
# geometry::PointCloud with 18367 points.
# geometry::PointCloud with 18383 points.
# geometry::PointCloud with 18396 points.
# geometry::PointCloud with 18410 points.
# geometry::PointCloud with 18415 points.
# geometry::PointCloud with 18428 points.
# geometry::PointCloud with 18437 points.
# geometry::PointCloud with 18444 points.
# geometry::PointCloud with 17071 points.
# geometry::PointCloud with 17129 points.
# geometry::PointCloud with 17190 points.
# geometry::PointCloud with 17227 points.
# geometry::PointCloud with 17408 points.
# geometry::PointCloud with 17431 points.
# geometry::PointCloud with 17454 points.
# geometry::PointCloud with 17481 points.
# geometry::PointCloud with 17510 points.
# geometry::PointCloud with 17635 points.
# geometry::PointCloud with 17654 points.
# geometry::PointCloud with 17668 points.
# geometry::PointCloud with 17695 points.
# geometry::PointCloud with 17719 points.
# geometry::PointCloud with 17735 points.
# geometry::PointCloud with 16249 points.
# geometry::PointCloud with 16492 points.
# geometry::PointCloud with 16179 points.
# geometry::PointCloud with 16087 points.
# geometry::PointCloud with 16310 points.
# geometry::PointCloud with 16047 points.
# geometry::PointCloud with 15888 points.
# geometry::PointCloud with 15869 points.
# geometry::PointCloud with 16134 points.
# geometry::PointCloud with 16032 points.
# geometry::PointCloud with 15778 points.
# geometry::PointCloud with 15673 points.
# geometry::PointCloud with 15677 points.
# geometry::PointCloud with 15713 points.
# geometry::PointCloud with 15776 points.
# geometry::PointCloud with 15845 points.
# geometry::PointCloud with 15708 points.
# geometry::PointCloud with 15695 points.
# geometry::PointCloud with 15757 points.
# geometry::PointCloud with 15645 points.
# geometry::PointCloud with 15659 points.
# geometry::PointCloud with 15714 points.
# geometry::PointCloud with 15690 points.
# geometry::PointCloud with 15804 points.
# geometry::PointCloud with 15914 points.
# geometry::PointCloud with 16030 points.
# geometry::PointCloud with 16092 points.
# geometry::PointCloud with 16161 points.
# geometry::PointCloud with 15634 points.
# geometry::PointCloud with 15704 points.
# geometry::PointCloud with 15822 points.
# geometry::PointCloud with 15928 points.
# geometry::PointCloud with 16279 points.
# geometry::PointCloud with 16340 points.
# geometry::PointCloud with 15575 points.
# geometry::PointCloud with 15623 points.
# geometry::PointCloud with 15529 points.
# geometry::PointCloud with 15526 points.
# geometry::PointCloud with 15546 points.
# geometry::PointCloud with 15575 points.
# geometry::PointCloud with 15567 points.
# geometry::PointCloud with 15598 points.
# geometry::PointCloud with 15638 points.
# geometry::PointCloud with 15672 points.
# geometry::PointCloud with 15629 points.
# geometry::PointCloud with 15534 points.
# geometry::PointCloud with 15646 points.
# geometry::PointCloud with 15599 points.
# geometry::PointCloud with 15589 points.
# geometry::PointCloud with 15620 points.
# geometry::PointCloud with 15669 points.
# geometry::PointCloud with 15629 points.
# geometry::PointCloud with 15539 points.
# geometry::PointCloud with 15380 points.
# geometry::PointCloud with 15387 points.
# geometry::PointCloud with 15522 points.
# geometry::PointCloud with 15557 points.
# geometry::PointCloud with 15424 points.
# geometry::PointCloud with 15492 points.
# geometry::PointCloud with 15506 points.
# geometry::PointCloud with 15497 points.
# geometry::PointCloud with 15546 points.
# geometry::PointCloud with 15588 points.
# geometry::PointCloud with 15652 points.
# geometry::PointCloud with 15655 points.
# geometry::PointCloud with 15731 points.
# geometry::PointCloud with 15523 points.
# geometry::PointCloud with 15524 points.
# geometry::PointCloud with 15620 points.
# geometry::PointCloud with 15628 points.
# geometry::PointCloud with 15507 points.
# geometry::PointCloud with 15381 points.
# geometry::PointCloud with 15522 points.
# geometry::PointCloud with 15538 points.
# geometry::PointCloud with 15568 points.
# geometry::PointCloud with 15409 points.
# geometry::PointCloud with 15456 points.
# geometry::PointCloud with 15387 points.
# geometry::PointCloud with 15376 points.
# geometry::PointCloud with 15407 points.
# geometry::PointCloud with 15458 points.
# geometry::PointCloud with 15451 points.
# geometry::PointCloud with 15501 points.
# geometry::PointCloud with 15530 points.
# geometry::PointCloud with 15505 points.
# geometry::PointCloud with 15530 points.
# geometry::PointCloud with 15505 points.
# geometry::PointCloud with 15430 points.
# geometry::PointCloud with 15730 points.
# geometry::PointCloud with 15816 points.
# geometry::PointCloud with 15866 points.
# geometry::PointCloud with 15415 points.
# geometry::PointCloud with 15404 points.
# geometry::PointCloud with 15479 points.
# geometry::PointCloud with 15340 points.
# geometry::PointCloud with 15395 points.
# geometry::PointCloud with 15352 points.
# geometry::PointCloud with 15399 points.
# geometry::PointCloud with 15466 points.
# geometry::PointCloud with 15464 points.
# geometry::PointCloud with 15560 points.
# geometry::PointCloud with 15675 points.
# geometry::PointCloud with 15608 points.
# geometry::PointCloud with 15551 points.
# geometry::PointCloud with 15607 points.
# geometry::PointCloud with 15912 points.
# geometry::PointCloud with 16169 points.
# geometry::PointCloud with 15661 points.
# geometry::PointCloud with 15828 points.
# geometry::PointCloud with 15865 points.
# geometry::PointCloud with 16170 points.
# geometry::PointCloud with 16455 points.
# geometry::PointCloud with 16608 points.
# geometry::PointCloud with 16701 points.
# geometry::PointCloud with 16797 points.
# geometry::PointCloud with 16914 points.
# geometry::PointCloud with 16993 points.
# geometry::PointCloud with 17088 points.
# geometry::PointCloud with 17156 points.
# geometry::PointCloud with 17270 points.
# geometry::PointCloud with 17325 points.
# geometry::PointCloud with 16306 points.
# geometry::PointCloud with 16514 points.
# geometry::PointCloud with 16324 points.
# geometry::PointCloud with 16313 points.
# geometry::PointCloud with 16421 points.
# geometry::PointCloud with 16394 points.
# geometry::PointCloud with 16401 points.
# geometry::PointCloud with 16484 points.
# geometry::PointCloud with 16179 points.
# geometry::PointCloud with 16279 points.
# geometry::PointCloud with 16487 points.
# geometry::PointCloud with 16622 points.
# geometry::PointCloud with 16382 points.
# geometry::PointCloud with 16565 points.
# geometry::PointCloud with 16484 points.
# geometry::PointCloud with 16649 points.
# geometry::PointCloud with 16825 points.
# geometry::PointCloud with 17010 points.
# geometry::PointCloud with 16586 points.
# geometry::PointCloud with 16726 points.
# geometry::PointCloud with 16858 points.
# geometry::PointCloud with 16580 points.
# geometry::PointCloud with 16701 points.
# geometry::PointCloud with 16928 points.
# geometry::PointCloud with 16624 points.
# geometry::PointCloud with 16716 points.
# geometry::PointCloud with 16630 points.
# geometry::PointCloud with 16904 points.
# geometry::PointCloud with 17061 points.
# geometry::PointCloud with 17189 points.
# geometry::PointCloud with 17317 points.
# geometry::PointCloud with 17438 points.
# geometry::PointCloud with 17507 points.
# geometry::PointCloud with 17605 points.
# geometry::PointCloud with 17410 points.
# geometry::PointCloud with 17558 points.
# geometry::PointCloud with 17578 points.
# geometry::PointCloud with 17687 points.
# geometry::PointCloud with 17844 points.
# geometry::PointCloud with 17827 points.
# geometry::PointCloud with 15722 points.
# geometry::PointCloud with 15923 points.
# geometry::PointCloud with 15144 points.
# geometry::PointCloud with 15447 points.
# geometry::PointCloud with 15087 points.
# geometry::PointCloud with 15288 points.
# geometry::PointCloud with 15417 points.
# geometry::PointCloud with 15131 points.
# geometry::PointCloud with 15198 points.
# geometry::PointCloud with 14996 points.
# geometry::PointCloud with 15022 points.
# geometry::PointCloud with 15209 points.
# geometry::PointCloud with 15250 points.
# geometry::PointCloud with 15325 points.
# geometry::PointCloud with 15448 points.
# geometry::PointCloud with 15459 points.
# geometry::PointCloud with 15618 points.
# geometry::PointCloud with 15542 points.
# geometry::PointCloud with 15787 points.
# geometry::PointCloud with 15939 points.
# geometry::PointCloud with 15825 points.
# geometry::PointCloud with 15904 points.
# geometry::PointCloud with 16102 points.
# geometry::PointCloud with 16154 points.
# geometry::PointCloud with 16063 points.
# geometry::PointCloud with 16134 points.
# geometry::PointCloud with 16183 points.
# geometry::PointCloud with 16191 points.
# geometry::PointCloud with 16051 points.
# geometry::PointCloud with 16146 points.
# geometry::PointCloud with 16035 points.
# geometry::PointCloud with 16128 points.
# geometry::PointCloud with 16236 points.
# geometry::PointCloud with 16385 points.
# geometry::PointCloud with 16337 points.
# geometry::PointCloud with 16431 points.
# geometry::PointCloud with 16510 points.
# geometry::PointCloud with 16200 points.
# geometry::PointCloud with 16326 points.
# geometry::PointCloud with 16409 points.
# geometry::PointCloud with 16484 points.
# geometry::PointCloud with 16128 points.
# geometry::PointCloud with 16117 points.
# geometry::PointCloud with 16165 points.
# geometry::PointCloud with 16250 points.
# geometry::PointCloud with 16409 points.
# geometry::PointCloud with 16570 points.
# geometry::PointCloud with 16674 points.
# geometry::PointCloud with 16708 points.
# geometry::PointCloud with 16810 points.
# geometry::PointCloud with 16887 points.
# geometry::PointCloud with 16950 points.
# geometry::PointCloud with 17072 points.
# geometry::PointCloud with 17212 points.
# geometry::PointCloud with 16874 points.
# geometry::PointCloud with 16949 points.
# geometry::PointCloud with 16876 points.
# geometry::PointCloud with 17019 points.
# geometry::PointCloud with 16613 points.
# geometry::PointCloud with 16589 points.
# geometry::PointCloud with 16697 points.
# geometry::PointCloud with 16777 points.
# geometry::PointCloud with 16878 points.
# geometry::PointCloud with 16990 points.
# geometry::PointCloud with 16973 points.
# geometry::PointCloud with 17074 points.
# geometry::PointCloud with 17134 points.
# geometry::PointCloud with 17190 points.
# geometry::PointCloud with 17341 points.
# geometry::PointCloud with 17404 points.
# geometry::PointCloud with 17478 points.
# geometry::PointCloud with 17676 points.
# geometry::PointCloud with 17720 points.
# geometry::PointCloud with 17360 points.
# geometry::PointCloud with 17496 points.
# geometry::PointCloud with 17274 points.
# geometry::PointCloud with 17404 points.
# geometry::PointCloud with 17106 points.
# geometry::PointCloud with 17253 points.
# geometry::PointCloud with 17199 points.
# geometry::PointCloud with 17298 points.
# geometry::PointCloud with 17366 points.
# geometry::PointCloud with 17429 points.
# geometry::PointCloud with 17463 points.
# geometry::PointCloud with 17278 points.
# geometry::PointCloud with 17459 points.
# geometry::PointCloud with 17464 points.
# geometry::PointCloud with 17536 points.
# geometry::PointCloud with 17503 points.
# geometry::PointCloud with 17610 points.
# geometry::PointCloud with 17655 points.
# geometry::PointCloud with 17767 points.
# geometry::PointCloud with 17555 points.
# geometry::PointCloud with 17552 points.
# geometry::PointCloud with 17536 points.
# geometry::PointCloud with 17771 points.
# geometry::PointCloud with 17641 points.
# geometry::PointCloud with 17751 points.
# geometry::PointCloud with 17891 points.
# geometry::PointCloud with 17970 points.
# geometry::PointCloud with 18133 points.
# geometry::PointCloud with 18291 points.
# geometry::PointCloud with 18348 points.
# geometry::PointCloud with 18404 points.
# geometry::PointCloud with 18356 points.
# geometry::PointCloud with 18159 points.
# geometry::PointCloud with 17857 points.
# geometry::PointCloud with 18000 points.
# geometry::PointCloud with 17747 points.
# geometry::PointCloud with 17853 points.
# geometry::PointCloud with 17647 points.
# geometry::PointCloud with 17773 points.
# geometry::PointCloud with 17913 points.
# geometry::PointCloud with 17664 points.
# geometry::PointCloud with 17761 points.
# geometry::PointCloud with 17786 points.
# geometry::PointCloud with 17722 points.
# geometry::PointCloud with 17940 points.
# geometry::PointCloud with 17605 points.
# geometry::PointCloud with 17767 points.
# geometry::PointCloud with 17930 points.
# geometry::PointCloud with 17730 points.
# geometry::PointCloud with 17672 points.
# geometry::PointCloud with 17949 points.
# geometry::PointCloud with 17716 points.
# geometry::PointCloud with 17745 points.
# geometry::PointCloud with 17840 points.
# geometry::PointCloud with 17895 points.
# geometry::PointCloud with 17875 points.
# geometry::PointCloud with 17726 points.
# geometry::PointCloud with 17815 points.
# geometry::PointCloud with 17798 points.
# geometry::PointCloud with 17802 points.
# geometry::PointCloud with 17803 points.
# geometry::PointCloud with 17619 points.
# geometry::PointCloud with 17738 points.
# geometry::PointCloud with 17807 points.
# geometry::PointCloud with 17813 points.
# geometry::PointCloud with 17658 points.
# geometry::PointCloud with 17658 points.
# geometry::PointCloud with 17602 points.
# geometry::PointCloud with 17551 points.
# geometry::PointCloud with 17596 points.
# geometry::PointCloud with 17692 points.
# geometry::PointCloud with 17578 points.
# geometry::PointCloud with 17566 points.
# geometry::PointCloud with 17691 points.
# geometry::PointCloud with 17771 points.
# geometry::PointCloud with 17862 points.
# geometry::PointCloud with 17640 points.
# geometry::PointCloud with 17815 points.
# geometry::PointCloud with 17747 points.
# geometry::PointCloud with 17859 points.
# geometry::PointCloud with 17790 points.
# geometry::PointCloud with 17581 points.
# geometry::PointCloud with 17673 points.
# geometry::PointCloud with 17728 points.
# geometry::PointCloud with 17784 points.
# geometry::PointCloud with 17628 points.
# geometry::PointCloud with 17532 points.
# geometry::PointCloud with 17529 points.
# geometry::PointCloud with 17626 points.
# geometry::PointCloud with 17544 points.
# geometry::PointCloud with 17553 points.
# geometry::PointCloud with 17721 points.
# geometry::PointCloud with 17805 points.
# geometry::PointCloud with 17734 points.
# geometry::PointCloud with 17569 points.
# geometry::PointCloud with 17589 points.
# geometry::PointCloud with 17481 points.
# geometry::PointCloud with 17575 points.
# geometry::PointCloud with 17769 points.
# geometry::PointCloud with 17560 points.
# geometry::PointCloud with 17581 points.
# geometry::PointCloud with 17650 points.
# geometry::PointCloud with 17518 points.
# geometry::PointCloud with 17537 points.
# geometry::PointCloud with 17655 points.
# geometry::PointCloud with 17722 points.
# geometry::PointCloud with 17672 points.
# geometry::PointCloud with 17668 points.
# geometry::PointCloud with 17771 points.
# geometry::PointCloud with 17640 points.
# geometry::PointCloud with 17711 points.
# geometry::PointCloud with 17523 points.
# geometry::PointCloud with 17585 points.
# geometry::PointCloud with 17686 points.
# geometry::PointCloud with 17702 points.
# geometry::PointCloud with 17756 points.
# geometry::PointCloud with 17706 points.
# geometry::PointCloud with 17699 points.
# geometry::PointCloud with 17695 points.
# geometry::PointCloud with 17834 points.
# geometry::PointCloud with 17809 points.
# geometry::PointCloud with 17565 points.
# geometry::PointCloud with 17806 points.
# geometry::PointCloud with 17751 points.
# geometry::PointCloud with 17835 points.
# geometry::PointCloud with 17977 points.
# geometry::PointCloud with 17857 points.
# geometry::PointCloud with 17909 points.
# geometry::PointCloud with 17673 points.
# geometry::PointCloud with 17733 points.
# geometry::PointCloud with 17681 points.
# geometry::PointCloud with 17791 points.
# geometry::PointCloud with 17811 points.
# geometry::PointCloud with 18109 points.
# geometry::PointCloud with 18257 points.
# geometry::PointCloud with 18199 points.
# geometry::PointCloud with 18325 points.
# geometry::PointCloud with 18492 points.
# geometry::PointCloud with 18078 points.
# geometry::PointCloud with 18213 points.
# geometry::PointCloud with 18124 points.
# geometry::PointCloud with 18057 points.
# geometry::PointCloud with 18199 points.
# geometry::PointCloud with 18105 points.
# geometry::PointCloud with 18276 points.
# geometry::PointCloud with 18367 points.
# geometry::PointCloud with 18551 points.
# geometry::PointCloud with 18370 points.
# geometry::PointCloud with 18589 points.
# geometry::PointCloud with 18753 points.
# geometry::PointCloud with 18413 points.
# geometry::PointCloud with 18406 points.
# geometry::PointCloud with 18418 points.
# geometry::PointCloud with 18344 points.
# geometry::PointCloud with 18398 points.
# geometry::PointCloud with 18315 points.
# geometry::PointCloud with 18402 points.
# geometry::PointCloud with 18636 points.
# geometry::PointCloud with 18688 points.
# geometry::PointCloud with 18472 points.
# geometry::PointCloud with 18504 points.
# geometry::PointCloud with 18617 points.
# geometry::PointCloud with 18713 points.
# geometry::PointCloud with 18808 points.
# geometry::PointCloud with 18882 points.
# geometry::PointCloud with 18539 points.
# geometry::PointCloud with 18591 points.
# geometry::PointCloud with 18737 points.
# geometry::PointCloud with 18640 points.
# geometry::PointCloud with 18669 points.
# geometry::PointCloud with 18783 points.
# geometry::PointCloud with 18911 points.
# geometry::PointCloud with 18813 points.
# geometry::PointCloud with 18804 points.
# geometry::PointCloud with 18912 points.
# geometry::PointCloud with 19157 points.
# geometry::PointCloud with 18962 points.
# geometry::PointCloud with 19217 points.
# geometry::PointCloud with 19394 points.
# geometry::PointCloud with 19432 points.
# geometry::PointCloud with 19491 points.
# geometry::PointCloud with 19323 points.
# geometry::PointCloud with 19401 points.
# geometry::PointCloud with 19463 points.
# geometry::PointCloud with 19411 points.
# geometry::PointCloud with 19395 points.
# geometry::PointCloud with 19672 points.
# geometry::PointCloud with 19969 points.
# geometry::PointCloud with 20302 points.
# geometry::PointCloud with 20596 points.
# geometry::PointCloud with 20750 points.
# geometry::PointCloud with 20885 points.
# geometry::PointCloud with 21046 points.
# geometry::PointCloud with 21213 points.
# geometry::PointCloud with 21321 points.
# geometry::PointCloud with 21554 points.
# geometry::PointCloud with 21638 points.
# geometry::PointCloud with 21753 points.
# geometry::PointCloud with 21826 points.
# geometry::PointCloud with 21968 points.
# geometry::PointCloud with 22155 points.
# geometry::PointCloud with 22269 points.
# geometry::PointCloud with 22455 points.
# geometry::PointCloud with 22586 points.
# geometry::PointCloud with 22688 points.
# geometry::PointCloud with 22820 points.
# geometry::PointCloud with 22937 points.
# geometry::PointCloud with 23049 points.
# geometry::PointCloud with 23149 points.
# geometry::PointCloud with 23278 points.
# geometry::PointCloud with 23386 points.
# geometry::PointCloud with 23443 points.
# geometry::PointCloud with 23546 points.
# geometry::PointCloud with 23637 points.
# geometry::PointCloud with 23709 points.
# geometry::PointCloud with 23790 points.
# geometry::PointCloud with 23847 points.
# geometry::PointCloud with 23957 points.
# geometry::PointCloud with 24057 points.
# geometry::PointCloud with 24150 points.
# geometry::PointCloud with 24215 points.
# geometry::PointCloud with 24278 points.
# geometry::PointCloud with 24359 points.
# geometry::PointCloud with 24434 points.
# geometry::PointCloud with 24478 points.
# geometry::PointCloud with 24548 points.
# geometry::PointCloud with 24616 points.
# geometry::PointCloud with 24693 points.
# geometry::PointCloud with 24769 points.
# geometry::PointCloud with 24816 points.
# geometry::PointCloud with 24912 points.
# geometry::PointCloud with 24969 points.
# geometry::PointCloud with 25045 points.
# geometry::PointCloud with 25092 points.
# geometry::PointCloud with 25175 points.
# geometry::PointCloud with 25237 points.
# geometry::PointCloud with 25301 points.
# geometry::PointCloud with 25373 points.
# geometry::PointCloud with 25461 points.
# geometry::PointCloud with 25538 points.
# geometry::PointCloud with 25599 points.
# geometry::PointCloud with 25676 points.
# geometry::PointCloud with 25753 points.
# geometry::PointCloud with 25837 points.
# geometry::PointCloud with 25898 points.
# geometry::PointCloud with 25976 points.
# geometry::PointCloud with 26020 points.
# geometry::PointCloud with 26081 points.
# geometry::PointCloud with 26138 points.
# geometry::PointCloud with 26199 points.
# geometry::PointCloud with 26258 points.
# geometry::PointCloud with 26318 points.
# geometry::PointCloud with 26382 points.
# geometry::PointCloud with 26440 points.
# geometry::PointCloud with 26483 points.
# geometry::PointCloud with 26526 points.
# geometry::PointCloud with 26574 points.
# geometry::PointCloud with 26619 points.
# geometry::PointCloud with 26670 points.
# geometry::PointCloud with 26718 points.
# geometry::PointCloud with 26754 points.
# geometry::PointCloud with 26803 points.
# geometry::PointCloud with 26841 points.
# geometry::PointCloud with 26892 points.
# geometry::PointCloud with 26928 points.
# geometry::PointCloud with 26968 points.
# geometry::PointCloud with 27009 points.
# geometry::PointCloud with 27057 points.
# geometry::PointCloud with 27097 points.
# geometry::PointCloud with 27143 points.
# geometry::PointCloud with 27187 points.
# geometry::PointCloud with 27224 points.
# geometry::PointCloud with 27252 points.
# geometry::PointCloud with 27297 points.
# geometry::PointCloud with 27330 points.
# geometry::PointCloud with 27407 points.
# geometry::PointCloud with 27441 points.
# geometry::PointCloud with 27485 points.
# geometry::PointCloud with 27526 points.
# geometry::PointCloud with 27565 points.
# geometry::PointCloud with 27596 points.
# geometry::PointCloud with 27614 points.
# geometry::PointCloud with 27625 points.
# geometry::PointCloud with 27642 points.
# geometry::PointCloud with 27660 points.
# geometry::PointCloud with 27672 points.
# geometry::PointCloud with 27683 points.
# geometry::PointCloud with 27703 points.
# geometry::PointCloud with 27719 points.
# geometry::PointCloud with 27733 points.
# geometry::PointCloud with 27753 points.
# geometry::PointCloud with 27759 points.
# geometry::PointCloud with 27765 points.
# geometry::PointCloud with 27775 points.
# geometry::PointCloud with 27788 points.
# geometry::PointCloud with 27800 points.
# geometry::PointCloud with 27807 points.
# geometry::PointCloud with 27812 points.
# geometry::PointCloud with 27813 points.
# geometry::PointCloud with 27820 points.
# geometry::PointCloud with 27825 points.
# geometry::PointCloud with 27833 points.
# geometry::PointCloud with 27835 points.
# geometry::PointCloud with 27842 points.
# geometry::PointCloud with 27843 points.
# geometry::PointCloud with 27845 points.
# geometry::PointCloud with 27848 points.
# geometry::PointCloud with 27851 points.
# geometry::PointCloud with 27879 points.
# geometry::PointCloud with 27881 points.
# geometry::PointCloud with 27883 points.
# geometry::PointCloud with 27889 points.
# geometry::PointCloud with 27894 points.
# geometry::PointCloud with 27897 points.
# geometry::PointCloud with 27904 points.
# geometry::PointCloud with 27913 points.
# geometry::PointCloud with 27932 points.
# geometry::PointCloud with 27944 points.
# geometry::PointCloud with 27954 points.
# geometry::PointCloud with 27969 points.
# geometry::PointCloud with 27981 points.
# geometry::PointCloud with 27989 points.
# geometry::PointCloud with 28010 points.
# geometry::PointCloud with 28037 points.
# geometry::PointCloud with 28052 points.
# geometry::PointCloud with 28061 points.
# geometry::PointCloud with 28074 points.
# geometry::PointCloud with 28089 points.
# geometry::PointCloud with 28107 points.
# geometry::PointCloud with 28121 points.
# geometry::PointCloud with 28140 points.
# geometry::PointCloud with 28164 points.
# geometry::PointCloud with 28195 points.
# geometry::PointCloud with 28213 points.
# geometry::PointCloud with 28230 points.
# geometry::PointCloud with 28243 points.
# geometry::PointCloud with 28262 points.
# geometry::PointCloud with 28268 points.
# geometry::PointCloud with 28279 points.
# geometry::PointCloud with 28284 points.
# geometry::PointCloud with 28291 points.
# geometry::PointCloud with 28297 points.
# geometry::PointCloud with 28302 points.
# geometry::PointCloud with 28309 points.
# geometry::PointCloud with 28317 points.
# geometry::PointCloud with 28328 points.
# geometry::PointCloud with 28347 points.
# geometry::PointCloud with 28373 points.
# geometry::PointCloud with 28382 points.
# geometry::PointCloud with 28391 points.
# geometry::PointCloud with 28399 points.
# geometry::PointCloud with 28406 points.
# geometry::PointCloud with 28411 points.
# geometry::PointCloud with 28418 points.
# geometry::PointCloud with 28423 points.
# geometry::PointCloud with 28440 points.
# geometry::PointCloud with 28445 points.
# geometry::PointCloud with 28453 points.
# geometry::PointCloud with 28459 points.
# geometry::PointCloud with 28466 points.
# geometry::PointCloud with 28476 points.
# geometry::PointCloud with 28498 points.
# geometry::PointCloud with 28511 points.
# geometry::PointCloud with 28515 points.
# geometry::PointCloud with 28521 points.
# geometry::PointCloud with 28530 points.
# geometry::PointCloud with 28537 points.
# geometry::PointCloud with 28551 points.
# geometry::PointCloud with 28566 points.
# geometry::PointCloud with 28581 points.
# geometry::PointCloud with 28591 points.
# geometry::PointCloud with 28604 points.
# geometry::PointCloud with 28627 points.
# geometry::PointCloud with 28634 points.
# geometry::PointCloud with 28647 points.
# geometry::PointCloud with 28660 points.
# geometry::PointCloud with 28672 points.
# geometry::PointCloud with 28692 points.
# geometry::PointCloud with 28724 points.
# geometry::PointCloud with 28744 points.
# geometry::PointCloud with 28766 points.
# geometry::PointCloud with 28801 points.
# geometry::PointCloud with 28842 points.
# geometry::PointCloud with 28879 points.
# geometry::PointCloud with 28914 points.
# geometry::PointCloud with 28953 points.
# geometry::PointCloud with 28989 points.
# geometry::PointCloud with 29040 points.
# geometry::PointCloud with 29084 points.
# geometry::PointCloud with 29113 points.
# geometry::PointCloud with 29156 points.
# geometry::PointCloud with 29194 points.
# geometry::PointCloud with 29227 points.
# geometry::PointCloud with 29260 points.
# geometry::PointCloud with 29314 points.
# geometry::PointCloud with 29355 points.
# geometry::PointCloud with 29408 points.
# geometry::PointCloud with 29445 points.
# geometry::PointCloud with 29505 points.
# geometry::PointCloud with 29553 points.
# geometry::PointCloud with 29599 points.
# geometry::PointCloud with 29650 points.
# geometry::PointCloud with 29699 points.
# geometry::PointCloud with 29764 points.
# geometry::PointCloud with 29824 points.
# geometry::PointCloud with 29877 points.
# geometry::PointCloud with 29951 points.
# geometry::PointCloud with 30020 points.
# geometry::PointCloud with 30094 points.
# geometry::PointCloud with 30159 points.
# geometry::PointCloud with 30247 points.
# geometry::PointCloud with 30421 points.
# geometry::PointCloud with 30562 points.
# geometry::PointCloud with 30690 points.
# geometry::PointCloud with 30855 points.
# geometry::PointCloud with 31021 points.
# geometry::PointCloud with 31172 points.
# geometry::PointCloud with 31362 points.
# geometry::PointCloud with 31554 points.
# geometry::PointCloud with 31653 points.
# geometry::PointCloud with 31771 points.
# geometry::PointCloud with 31854 points.
# geometry::PointCloud with 31919 points.
# geometry::PointCloud with 32077 points.
# geometry::PointCloud with 32187 points.
# geometry::PointCloud with 32246 points.
# geometry::PointCloud with 32318 points.
# geometry::PointCloud with 32375 points.
# geometry::PointCloud with 32455 points.
# geometry::PointCloud with 32525 points.
# geometry::PointCloud with 32570 points.
# geometry::PointCloud with 32607 points.
# geometry::PointCloud with 32643 points.
# geometry::PointCloud with 32677 points.
# geometry::PointCloud with 32740 points.
# geometry::PointCloud with 32813 points.
# geometry::PointCloud with 32931 points.
# geometry::PointCloud with 33150 points.
# geometry::PointCloud with 33203 points.
# geometry::PointCloud with 33271 points.
# geometry::PointCloud with 33333 points.
# geometry::PointCloud with 33359 points.
# geometry::PointCloud with 33379 points.
# geometry::PointCloud with 33410 points.
# geometry::PointCloud with 33442 points.
# geometry::PointCloud with 33471 points.
# geometry::PointCloud with 33489 points.
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# geometry::PointCloud with 35083 points.
# geometry::PointCloud with 35093 points.
# geometry::PointCloud with 35109 points.
# geometry::PointCloud with 35119 points.
# geometry::PointCloud with 35140 points.
# geometry::PointCloud with 35154 points.
# geometry::PointCloud with 35160 points.
# geometry::PointCloud with 35164 points.
# geometry::PointCloud with 35178 points.
# geometry::PointCloud with 35194 points.
# geometry::PointCloud with 35205 points.
# geometry::PointCloud with 35212 points.
# geometry::PointCloud with 35223 points.
# geometry::PointCloud with 35326 points.
# geometry::PointCloud with 35341 points.
# geometry::PointCloud with 35357 points.
# geometry::PointCloud with 35381 points.
# geometry::PointCloud with 35389 points.
# geometry::PointCloud with 35405 points.
# geometry::PointCloud with 35433 points.
# geometry::PointCloud with 35444 points.
# geometry::PointCloud with 35447 points.
# geometry::PointCloud with 35450 points.
# geometry::PointCloud with 35459 points.
# geometry::PointCloud with 35466 points.
# geometry::PointCloud with 35475 points.
# geometry::PointCloud with 35482 points.
# geometry::PointCloud with 35487 points.
# geometry::PointCloud with 35497 points.
# geometry::PointCloud with 35507 points.
# geometry::PointCloud with 35527 points.
# geometry::PointCloud with 35539 points.
# geometry::PointCloud with 35544 points.
# geometry::PointCloud with 35554 points.
# geometry::PointCloud with 35559 points.
# geometry::PointCloud with 35563 points.
# geometry::PointCloud with 35570 points.
# geometry::PointCloud with 35577 points.
# geometry::PointCloud with 35580 points.
# geometry::PointCloud with 35585 points.
# geometry::PointCloud with 35595 points.
# geometry::PointCloud with 35608 points.
# geometry::PointCloud with 35617 points.
# geometry::PointCloud with 35640 points.
# geometry::PointCloud with 35661 points.
# geometry::PointCloud with 35675 points.
# geometry::PointCloud with 35685 points.
# geometry::PointCloud with 35712 points.
# geometry::PointCloud with 35733 points.
# geometry::PointCloud with 35750 points.
# geometry::PointCloud with 35777 points.
# geometry::PointCloud with 35795 points.
# geometry::PointCloud with 35848 points.
# geometry::PointCloud with 35878 points.
# geometry::PointCloud with 35906 points.
# geometry::PointCloud with 35932 points.
# geometry::PointCloud with 35966 points.
# geometry::PointCloud with 35996 points.
# geometry::PointCloud with 36030 points.
# geometry::PointCloud with 36056 points.
# ...
# geometry::PointCloud with 44913 points.
# geometry::PointCloud with 44922 points.
# geometry::PointCloud with 44939 points.
# geometry::PointCloud with 44948 points.
# geometry::PointCloud with 44958 points.
# geometry::PointCloud with 44959 points.
# geometry::PointCloud with 44962 points.
# geometry::PointCloud with 44972 points.
# geometry::PointCloud with 44975 points.
# geometry::PointCloud with 44979 points.
# geometry::PointCloud with 44981 points.
# geometry::PointCloud with 44988 points.
# geometry::PointCloud with 45011 points.
# geometry::PointCloud with 45014 points.
# geometry::PointCloud with 45021 points.
# geometry::PointCloud with 45025 points.
# geometry::PointCloud with 45032 points.
# geometry::PointCloud with 45040 points.
# geometry::PointCloud with 45051 points.
# geometry::PointCloud with 45058 points.
# geometry::PointCloud with 45062 points.
# geometry::PointCloud with 45089 points.
# geometry::PointCloud with 45097 points.
# geometry::PointCloud with 45105 points.
# geometry::PointCloud with 45112 points.
# geometry::PointCloud with 45127 points.
# geometry::PointCloud with 45132 points.
# geometry::PointCloud with 45138 points.
# geometry::PointCloud with 45146 points.
# geometry::PointCloud with 45150 points.
# geometry::PointCloud with 45157 points.
# geometry::PointCloud with 45169 points.
# geometry::PointCloud with 45172 points.
# geometry::PointCloud with 45180 points.
# geometry::PointCloud with 45189 points.
# geometry::PointCloud with 45192 points.
# geometry::PointCloud with 45202 points.
# geometry::PointCloud with 45219 points.
# geometry::PointCloud with 45231 points.
# geometry::PointCloud with 45237 points.
# geometry::PointCloud with 45243 points.
# geometry::PointCloud with 45263 points.
# geometry::PointCloud with 45274 points.
# geometry::PointCloud with 45279 points.
# geometry::PointCloud with 45293 points.
# geometry::PointCloud with 45302 points.
# geometry::PointCloud with 45314 points.
# geometry::PointCloud with 45325 points.
# geometry::PointCloud with 45330 points.
# geometry::PointCloud with 45334 points.
# geometry::PointCloud with 45338 points.
# geometry::PointCloud with 45345 points.
# geometry::PointCloud with 45351 points.
# geometry::PointCloud with 45361 points.
# geometry::PointCloud with 45369 points.
# geometry::PointCloud with 45374 points.
# geometry::PointCloud with 45379 points.
# geometry::PointCloud with 45385 points.
# geometry::PointCloud with 45393 points.
# geometry::PointCloud with 45400 points.
# geometry::PointCloud with 45408 points.
# geometry::PointCloud with 45410 points.
# geometry::PointCloud with 45419 points.
# geometry::PointCloud with 45424 points.
# geometry::PointCloud with 45430 points.
# geometry::PointCloud with 45436 points.
# geometry::PointCloud with 45438 points.
# geometry::PointCloud with 45441 points.
# geometry::PointCloud with 45450 points.
# geometry::PointCloud with 45454 points.
# geometry::PointCloud with 45461 points.
# geometry::PointCloud with 45467 points.
# geometry::PointCloud with 45481 points.
# geometry::PointCloud with 45487 points.
# geometry::PointCloud with 45495 points.
# geometry::PointCloud with 45499 points.
# geometry::PointCloud with 45508 points.
# geometry::PointCloud with 45518 points.
# geometry::PointCloud with 45521 points.
# geometry::PointCloud with 45536 points.
# geometry::PointCloud with 45542 points.
# geometry::PointCloud with 45548 points.
# geometry::PointCloud with 45557 points.
# geometry::PointCloud with 45580 points.
# geometry::PointCloud with 45592 points.
# geometry::PointCloud with 45603 points.
# geometry::PointCloud with 45605 points.
# geometry::PointCloud with 45613 points.
# geometry::PointCloud with 45621 points.
# geometry::PointCloud with 45633 points.
# geometry::PointCloud with 45648 points.
# geometry::PointCloud with 45657 points.
# geometry::PointCloud with 45667 points.
# geometry::PointCloud with 45678 points.
# geometry::PointCloud with 45682 points.
# geometry::PointCloud with 45691 points.
# geometry::PointCloud with 45701 points.
# geometry::PointCloud with 45707 points.
# geometry::PointCloud with 45722 points.
# geometry::PointCloud with 45727 points.
# geometry::PointCloud with 45736 points.
# geometry::PointCloud with 45744 points.
# geometry::PointCloud with 45749 points.
# geometry::PointCloud with 45759 points.
# geometry::PointCloud with 45764 points.
# geometry::PointCloud with 45770 points.
# geometry::PointCloud with 45781 points.
# geometry::PointCloud with 45797 points.
# geometry::PointCloud with 45805 points.
# geometry::PointCloud with 45812 points.
# geometry::PointCloud with 45820 points.
# geometry::PointCloud with 45823 points.
# geometry::PointCloud with 45831 points.
# geometry::PointCloud with 45833 points.
# geometry::PointCloud with 45839 points.
# geometry::PointCloud with 45844 points.
# geometry::PointCloud with 45847 points.
# geometry::PointCloud with 45851 points.
# geometry::PointCloud with 45851 points.
# geometry::PointCloud with 45853 points.
# geometry::PointCloud with 45854 points.
# geometry::PointCloud with 45856 points.
# geometry::PointCloud with 45859 points.
# geometry::PointCloud with 45861 points.
# geometry::PointCloud with 45864 points.
# geometry::PointCloud with 45869 points.
# geometry::PointCloud with 45870 points.
# geometry::PointCloud with 45874 points.
# geometry::PointCloud with 45874 points.
# geometry::PointCloud with 45874 points.
# geometry::PointCloud with 45875 points.
# geometry::PointCloud with 45875 points.
# geometry::PointCloud with 45877 points.
# geometry::PointCloud with 45880 points.
# geometry::PointCloud with 45880 points.
# geometry::PointCloud with 45881 points.
# geometry::PointCloud with 45882 points.
# geometry::PointCloud with 45883 points.
# geometry::PointCloud with 45885 points.
# geometry::PointCloud with 45886 points.
# geometry::PointCloud with 45888 points.
# geometry::PointCloud with 45889 points.
# geometry::PointCloud with 45889 points.
# geometry::PointCloud with 45890 points.
# geometry::PointCloud with 45892 points.
# geometry::PointCloud with 45894 points.
# geometry::PointCloud with 45894 points.
# geometry::PointCloud with 45896 points.
# geometry::PointCloud with 45896 points.
# geometry::PointCloud with 45897 points.
# geometry::PointCloud with 45899 points.
# geometry::PointCloud with 45905 points.
# geometry::PointCloud with 45905 points.
# geometry::PointCloud with 45907 points.
# geometry::PointCloud with 45908 points.
# geometry::PointCloud with 45909 points.
# geometry::PointCloud with 45912 points.
# geometry::PointCloud with 45914 points.
# geometry::PointCloud with 45914 points.
# geometry::PointCloud with 45914 points.
# geometry::PointCloud with 45914 points.
# geometry::PointCloud with 45914 points.
# geometry::PointCloud with 45915 points.
# geometry::PointCloud with 45915 points.
# geometry::PointCloud with 45915 points.
# geometry::PointCloud with 45915 points.
# geometry::PointCloud with 45915 points.
# geometry::PointCloud with 45915 points.
# geometry::PointCloud with 45916 points.
# geometry::PointCloud with 45916 points.
# geometry::PointCloud with 45917 points.
# geometry::PointCloud with 45919 points.
# geometry::PointCloud with 45919 points.
# geometry::PointCloud with 45920 points.
# geometry::PointCloud with 45924 points.
# geometry::PointCloud with 45924 points.
# geometry::PointCloud with 45924 points.
# geometry::PointCloud with 45925 points.
# geometry::PointCloud with 45927 points.
# geometry::PointCloud with 45929 points.
# geometry::PointCloud with 45930 points.
# geometry::PointCloud with 45934 points.
# geometry::PointCloud with 45935 points.
# geometry::PointCloud with 45939 points.
# geometry::PointCloud with 45943 points.
# geometry::PointCloud with 45944 points.
# geometry::PointCloud with 45946 points.
# geometry::PointCloud with 45948 points.
# geometry::PointCloud with 45948 points.
# geometry::PointCloud with 45954 points.
# geometry::PointCloud with 45958 points.
# geometry::PointCloud with 45963 points.
# geometry::PointCloud with 45966 points.
# geometry::PointCloud with 45968 points.
# geometry::PointCloud with 45977 points.
# geometry::PointCloud with 45984 points.
# geometry::PointCloud with 45992 points.
# geometry::PointCloud with 46001 points.
# geometry::PointCloud with 46007 points.
# geometry::PointCloud with 46011 points.
# geometry::PointCloud with 46020 points.
# geometry::PointCloud with 46027 points.
# geometry::PointCloud with 46035 points.
# geometry::PointCloud with 46042 points.
# geometry::PointCloud with 46047 points.
# geometry::PointCloud with 46075 points.
# geometry::PointCloud with 46084 points.
# geometry::PointCloud with 46091 points.
# geometry::PointCloud with 46099 points.
# geometry::PointCloud with 46107 points.
# geometry::PointCloud with 46118 points.
# geometry::PointCloud with 46130 points.
# geometry::PointCloud with 46142 points.
# geometry::PointCloud with 46153 points.
# geometry::PointCloud with 46168 points.
# geometry::PointCloud with 46178 points.
# geometry::PointCloud with 46186 points.
# geometry::PointCloud with 46197 points.
# geometry::PointCloud with 46208 points.
# geometry::PointCloud with 46218 points.
# geometry::PointCloud with 46231 points.
# geometry::PointCloud with 46233 points.
# geometry::PointCloud with 46237 points.
# geometry::PointCloud with 46245 points.
# geometry::PointCloud with 46253 points.
# geometry::PointCloud with 46262 points.
# geometry::PointCloud with 46267 points.
# geometry::PointCloud with 46273 points.
# geometry::PointCloud with 46277 points.
# geometry::PointCloud with 46278 points.
# geometry::PointCloud with 46280 points.
# geometry::PointCloud with 46291 points.
# geometry::PointCloud with 46294 points.
# geometry::PointCloud with 46298 points.
# geometry::PointCloud with 46307 points.
# geometry::PointCloud with 46308 points.
# geometry::PointCloud with 46312 points.
# geometry::PointCloud with 46315 points.
# geometry::PointCloud with 46322 points.
# geometry::PointCloud with 46326 points.
# geometry::PointCloud with 46330 points.
# geometry::PointCloud with 46332 points.
# geometry::PointCloud with 46336 points.
# geometry::PointCloud with 46336 points.
# geometry::PointCloud with 46337 points.
# geometry::PointCloud with 46340 points.
# geometry::PointCloud with 46340 points.
# geometry::PointCloud with 46365 points.
# geometry::PointCloud with 46369 points.
# geometry::PointCloud with 46372 points.
# geometry::PointCloud with 46382 points.
# geometry::PointCloud with 46388 points.
# geometry::PointCloud with 46389 points.
# geometry::PointCloud with 46403 points.
# geometry::PointCloud with 46413 points.
# geometry::PointCloud with 46415 points.
# geometry::PointCloud with 46425 points.
# geometry::PointCloud with 46429 points.
# geometry::PointCloud with 46440 points.
# geometry::PointCloud with 46447 points.
# geometry::PointCloud with 46448 points.
# geometry::PointCloud with 46450 points.
# geometry::PointCloud with 46459 points.
# geometry::PointCloud with 46466 points.
# geometry::PointCloud with 46468 points.
# geometry::PointCloud with 46469 points.
# geometry::PointCloud with 46473 points.
# geometry::PointCloud with 46484 points.
# geometry::PointCloud with 46510 points.
# geometry::PointCloud with 46517 points.
# geometry::PointCloud with 46520 points.
# geometry::PointCloud with 46530 points.
# geometry::PointCloud with 46536 points.
# geometry::PointCloud with 46541 points.
# geometry::PointCloud with 46545 points.
# geometry::PointCloud with 46547 points.
# geometry::PointCloud with 46550 points.
# geometry::PointCloud with 46551 points.
# geometry::PointCloud with 46553 points.
# geometry::PointCloud with 46560 points.
# geometry::PointCloud with 46585 points.
# geometry::PointCloud with 46601 points.
# geometry::PointCloud with 46614 points.
# geometry::PointCloud with 46619 points.
# geometry::PointCloud with 46623 points.
# geometry::PointCloud with 46624 points.
# geometry::PointCloud with 46624 points.
# geometry::PointCloud with 46624 points.
# geometry::PointCloud with 46625 points.
# geometry::PointCloud with 46626 points.
# geometry::PointCloud with 46626 points.
# geometry::PointCloud with 46629 points.
# geometry::PointCloud with 46630 points.
# geometry::PointCloud with 46631 points.
# geometry::PointCloud with 46633 points.
# geometry::PointCloud with 46636 points.
# geometry::PointCloud with 46638 points.
# geometry::PointCloud with 46638 points.
# geometry::PointCloud with 46647 points.
# geometry::PointCloud with 46649 points.
# geometry::PointCloud with 46653 points.
# geometry::PointCloud with 46659 points.
# geometry::PointCloud with 46665 points.
# geometry::PointCloud with 46667 points.
# geometry::PointCloud with 46669 points.
# geometry::PointCloud with 46674 points.
# geometry::PointCloud with 46676 points.
# geometry::PointCloud with 46678 points.
# geometry::PointCloud with 46679 points.
# geometry::PointCloud with 46681 points.
# geometry::PointCloud with 46683 points.
# geometry::PointCloud with 46685 points.
# geometry::PointCloud with 46687 points.
# geometry::PointCloud with 46692 points.
# geometry::PointCloud with 46698 points.
# geometry::PointCloud with 46706 points.
# geometry::PointCloud with 46707 points.
# geometry::PointCloud with 46710 points.
# geometry::PointCloud with 46716 points.
# geometry::PointCloud with 46717 points.
# geometry::PointCloud with 46718 points.
# geometry::PointCloud with 46720 points.
# geometry::PointCloud with 46721 points.
# geometry::PointCloud with 46721 points.
# geometry::PointCloud with 46732 points.
# geometry::PointCloud with 46735 points.
# geometry::PointCloud with 46740 points.
# geometry::PointCloud with 46742 points.
# geometry::PointCloud with 46748 points.
# geometry::PointCloud with 46748 points.
# geometry::PointCloud with 46748 points.
# geometry::PointCloud with 46748 points.
# geometry::PointCloud with 46749 points.
# geometry::PointCloud with 46749 points.
# geometry::PointCloud with 46749 points.
# geometry::PointCloud with 46751 points.
# geometry::PointCloud with 46751 points.
# geometry::PointCloud with 46759 points.
# geometry::PointCloud with 46760 points.
# geometry::PointCloud with 46770 points.
# geometry::PointCloud with 46774 points.
# geometry::PointCloud with 46776 points.
# geometry::PointCloud with 46777 points.
# geometry::PointCloud with 46777 points.
# geometry::PointCloud with 46780 points.
# geometry::PointCloud with 46782 points.
# geometry::PointCloud with 46785 points.
# geometry::PointCloud with 46787 points.
# geometry::PointCloud with 46792 points.
# geometry::PointCloud with 46795 points.
# geometry::PointCloud with 46799 points.
# geometry::PointCloud with 46802 points.
# geometry::PointCloud with 46807 points.
# geometry::PointCloud with 46810 points.
# geometry::PointCloud with 46811 points.
# geometry::PointCloud with 46813 points.
# geometry::PointCloud with 46816 points.
# geometry::PointCloud with 46816 points.
# geometry::PointCloud with 46819 points.
# geometry::PointCloud with 46820 points.
# geometry::PointCloud with 46821 points.
# geometry::PointCloud with 46823 points.
# geometry::PointCloud with 46825 points.
# geometry::PointCloud with 46827 points.
# geometry::PointCloud with 46829 points.
# geometry::PointCloud with 46829 points.
# geometry::PointCloud with 46832 points.
# geometry::PointCloud with 46834 points.
# geometry::PointCloud with 46834 points.
# geometry::PointCloud with 46836 points.
# geometry::PointCloud with 46839 points.
# geometry::PointCloud with 46840 points.
# geometry::PointCloud with 46843 points.
# geometry::PointCloud with 46847 points.
# geometry::PointCloud with 46848 points.
# geometry::PointCloud with 46849 points.
# geometry::PointCloud with 46850 points.
# geometry::PointCloud with 46850 points.
# geometry::PointCloud with 46852 points.
# geometry::PointCloud with 46852 points.
# geometry::PointCloud with 46857 points.
# geometry::PointCloud with 46858 points.
# geometry::PointCloud with 46860 points.
# geometry::PointCloud with 46860 points.
# geometry::PointCloud with 46861 points.
# geometry::PointCloud with 46861 points.
# geometry::PointCloud with 46862 points.
# geometry::PointCloud with 46863 points.
# geometry::PointCloud with 46863 points.
# geometry::PointCloud with 46863 points.
# geometry::PointCloud with 46863 points.
# geometry::PointCloud with 46863 points.
# geometry::PointCloud with 46864 points.
# geometry::PointCloud with 46864 points.
# geometry::PointCloud with 46865 points.
# geometry::PointCloud with 46868 points.
# geometry::PointCloud with 46870 points.
# geometry::PointCloud with 46871 points.
# geometry::PointCloud with 46871 points.
# geometry::PointCloud with 46871 points.

# %% [markdown]
# #### Verifying completing of SLAM iterations

# %%
pcd_idx

# %%
map_pcd

# %% [markdown]
# ### Analysis

# %% [markdown]
# #### Look at the Map

# %%
map_pcd

# %%
draw_pcd(map_pcd, where='mat_3d')
draw_pcd(map_pcd, where='mat_2d')

# %%
draw_pcd(map_pcd, where='opn_nb')

# %% [markdown]
# #### Look at the Poses

# %%
df_pose = pd.DataFrame(pose_list)

# %%
plt.scatter(df_pose['x'], df_pose['y'])

# %% [markdown]
# #### Did we hit the velocity boundary ?

# %%
df_pose['x_abs'] = [0] + [df_pose.iloc[idx]['x_vel']- df_pose.iloc[idx-1]['x_vel'] for idx in range(df_pose.shape[0]) if idx != 0]
df_pose['y_abs'] = [0] + [df_pose.iloc[idx]['y_vel']- df_pose.iloc[idx-1]['y_vel'] for idx in range(df_pose.shape[0]) if idx != 0]
df_pose['theta_abs'] = [0] + [df_pose.iloc[idx]['theta_vel']- df_pose.iloc[idx-1]['theta_vel'] for idx in range(df_pose.shape[0]) if idx != 0]

# %% [raw]
# print(X_GRID[0], X_GRID[-1])
# print(df_pose['x_abs'].min(), df_pose['x_abs'].max())
# print("")
# print(Y_GRID[0], Y_GRID[-1])
# print(df_pose['y_abs'].min(), df_pose['y_abs'].max())
# print("")
# print(THETA_GRID[0], THETA_GRID[-1])
# print(df_pose['theta_abs'].min(), df_pose['theta_abs'].max())

# %%
if df_pose['x_abs'].min() <= X_GRID[0]:
    print("Velocity boundary hit in -X direction")
    print("Expected: {} | Real : {}".format(X_GRID[0], df_pose['x_abs'].min()))

if df_pose['y_abs'].min() <= Y_GRID[0]:
    print("Velocity boundary hit in -Y direction")
    print("Expected: {} | Real : {}".format(Y_GRID[0], df_pose['y_abs'].min()))
    
if df_pose['theta_abs'].min() <= THETA_GRID[0]:
    print("Velocity boundary hit in -THETA direction")
    print("Expected: {} | Real : {}".format(THETA_GRID[0], df_pose['theta_abs'].min()))
    
if df_pose['x_abs'].max() >= X_GRID[-1]:
    print("Velocity boundary hit in +X direction")
    print("Expected: {} | Real : {}".format(X_GRID[-1], df_pose['x_abs'].max()))
    
if df_pose['y_abs'].max() >= Y_GRID[-1]:
    print("Velocity boundary hit in +Y direction")
    print("Expected: {} | Real : {}".format(Y_GRID[-1], df_pose['y_abs'].max()))

if df_pose['theta_abs'].max() >= THETA_GRID[-1]:
    print("Velocity boundary hit in +THETA direction")
    print("Expected: {} | Real : {}".format(THETA_GRID[-1], df_pose['theta_abs'].max()))
    
print("All clear?")
